# %% [markdown]
# This is one of the deliverables produced from this project: https://library.hkust.edu.hk/ds/project/p002/
#
# > This notebook is created by Holly CHAN (HKUST Library) for generating the figures as presented in our article in IFLA's TILT (Jan 2025 Issue)

# %% [markdown]
# # Face recognition using `deepface` library

# %%
# https://github.com/serengil/deepface
from deepface import DeepFace

# %%
unknown_face_dir = 'cropped_face'
known_face_dir = 'known_face'
model_name = 'Facenet'

# Get the list of known faces
known_faces = [f for f in os.listdir(known_face_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

results = {}

# Process each unknown face
for unknown_face in os.listdir(unknown_face_dir):
    if unknown_face.endswith(('.png', '.jpg', '.jpeg')):
        unknown_face_path = os.path.join(unknown_face_dir, unknown_face)
        results[unknown_face] = {}

        for known_face in known_faces:
            known_face_path = os.path.join(known_face_dir, known_face)
            try:
                # Perform face verification
                verification_results = DeepFace.verify(img1_path=known_face_path, img2_path=unknown_face_path, model_name=model_name)
                verified = verification_results['verified']
                results[unknown_face][known_face] = verified
                print(f"{unknown_face} vs {known_face}: {verified}")
            except Exception as e:
                results[unknown_face][known_face] = "Fail"
                print(f"Error processing {unknown_face} vs {known_face}: {str(e)}")

# Export
results_df = pd.DataFrame.from_dict(results, orient='index')
results_df.index.name = 'Unknown Face'
results_df.to_csv('face_verification_results__deepface.csv')
# Out:
# 143-1_0.jpg vs chang.png: False
# 143-1_0.jpg vs chung.png: False
# 143-1_0.jpg vs ng.png: False
# 143-1_1.jpg vs chang.png: False
# 143-1_1.jpg vs chung.png: False
# 143-1_1.jpg vs ng.png: False
# Error processing 143-1_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 143-1_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 143-1_2.jpg vs ng.png: Exception while processing img2_path
# 143-1_3.jpg vs chang.png: True
# 143-1_3.jpg vs chung.png: False
# 143-1_3.jpg vs ng.png: False
# Error processing 143-1_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 143-1_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 143-1_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 143-1_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 143-1_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 143-1_5.jpg vs ng.png: Exception while processing img2_path
# 161-2_0.jpg vs chang.png: False
# 161-2_0.jpg vs chung.png: False
# 161-2_0.jpg vs ng.png: False
# 161-2_1.jpg vs chang.png: True
# 161-2_1.jpg vs chung.png: False
# 161-2_1.jpg vs ng.png: False
# 161-2_2.jpg vs chang.png: True
# 161-2_2.jpg vs chung.png: False
# 161-2_2.jpg vs ng.png: False
# 172-25_0.jpg vs chang.png: False
# 172-25_0.jpg vs chung.png: False
# 172-25_0.jpg vs ng.png: False
# Error processing 172-25_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 172-25_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 172-25_1.jpg vs ng.png: Exception while processing img2_path
# 172-25_2.jpg vs chang.png: False
# 172-25_2.jpg vs chung.png: False
# 172-25_2.jpg vs ng.png: False
# Error processing 172-25_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 172-25_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 172-25_3.jpg vs ng.png: Exception while processing img2_path
# 183-23_0.jpg vs chang.png: True
# 183-23_0.jpg vs chung.png: False
# 183-23_0.jpg vs ng.png: False
# 183-23_1.jpg vs chang.png: False
# 183-23_1.jpg vs chung.png: False
# 183-23_1.jpg vs ng.png: False
# 183-23_2.jpg vs chang.png: False
# 183-23_2.jpg vs chung.png: False
# 183-23_2.jpg vs ng.png: False
# 196-1_0.jpg vs chang.png: True
# 196-1_0.jpg vs chung.png: False
# 196-1_0.jpg vs ng.png: False
# 196-1_1.jpg vs chang.png: False
# 196-1_1.jpg vs chung.png: False
# 196-1_1.jpg vs ng.png: False
# 196-1_2.jpg vs chang.png: False
# 196-1_2.jpg vs chung.png: False
# 196-1_2.jpg vs ng.png: False
# Error processing 196-1_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 196-1_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 196-1_3.jpg vs ng.png: Exception while processing img2_path
# 282-32_0.jpg vs chang.png: False
# 282-32_0.jpg vs chung.png: False
# 282-32_0.jpg vs ng.png: False
# Error processing 282-32_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 282-32_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 282-32_1.jpg vs ng.png: Exception while processing img2_path
# 282-32_2.jpg vs chang.png: False
# 282-32_2.jpg vs chung.png: False
# 282-32_2.jpg vs ng.png: False
# Error processing 282-32_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 282-32_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 282-32_3.jpg vs ng.png: Exception while processing img2_path
# 290-8_0.jpg vs chang.png: False
# 290-8_0.jpg vs chung.png: False
# 290-8_0.jpg vs ng.png: False
# Error processing 290-8_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 290-8_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 290-8_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 290-8_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 290-8_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 290-8_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 290-8_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 290-8_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 290-8_3.jpg vs ng.png: Exception while processing img2_path
# 313-13_0.jpg vs chang.png: True
# 313-13_0.jpg vs chung.png: False
# 313-13_0.jpg vs ng.png: False
# 313-13_1.jpg vs chang.png: True
# 313-13_1.jpg vs chung.png: False
# 313-13_1.jpg vs ng.png: False
# 313-13_2.jpg vs chang.png: False
# 313-13_2.jpg vs chung.png: False
# 313-13_2.jpg vs ng.png: False
# Error processing 313-13_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 313-13_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 313-13_3.jpg vs ng.png: Exception while processing img2_path
# 330-2_0.jpg vs chang.png: False
# 330-2_0.jpg vs chung.png: False
# 330-2_0.jpg vs ng.png: False
# Error processing 330-2_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 330-2_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 330-2_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 330-2_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 330-2_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 330-2_2.jpg vs ng.png: Exception while processing img2_path
# 357-8_0.jpg vs chang.png: False
# 357-8_0.jpg vs chung.png: True
# 357-8_0.jpg vs ng.png: True
# Error processing 357-8_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 357-8_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 357-8_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 357-8_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 357-8_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 357-8_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 357-8_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 357-8_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 357-8_3.jpg vs ng.png: Exception while processing img2_path
# 358-9_0.jpg vs chang.png: False
# 358-9_0.jpg vs chung.png: False
# 358-9_0.jpg vs ng.png: False
# 358-9_1.jpg vs chang.png: False
# 358-9_1.jpg vs chung.png: True
# 358-9_1.jpg vs ng.png: True
# Error processing 358-9_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 358-9_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 358-9_2.jpg vs ng.png: Exception while processing img2_path
# 358-9_3.jpg vs chang.png: True
# 358-9_3.jpg vs chung.png: False
# 358-9_3.jpg vs ng.png: False
# Error processing 358-9_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 358-9_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 358-9_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 358-9_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 358-9_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 358-9_5.jpg vs ng.png: Exception while processing img2_path
# Error processing 360-25_0.jpg vs chang.png: Exception while processing img2_path
# Error processing 360-25_0.jpg vs chung.png: Exception while processing img2_path
# Error processing 360-25_0.jpg vs ng.png: Exception while processing img2_path
# Error processing 360-25_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 360-25_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 360-25_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 360-25_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 360-25_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 360-25_2.jpg vs ng.png: Exception while processing img2_path
# 360-25_3.jpg vs chang.png: False
# 360-25_3.jpg vs chung.png: False
# 360-25_3.jpg vs ng.png: False
# Error processing 360-25_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 360-25_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 360-25_4.jpg vs ng.png: Exception while processing img2_path
# 366-1_0.jpg vs chang.png: False
# 366-1_0.jpg vs chung.png: False
# 366-1_0.jpg vs ng.png: False
# 366-1_1.jpg vs chang.png: False
# 366-1_1.jpg vs chung.png: False
# 366-1_1.jpg vs ng.png: False
# 366-1_2.jpg vs chang.png: False
# 366-1_2.jpg vs chung.png: False
# 366-1_2.jpg vs ng.png: False
# 366-1_3.jpg vs chang.png: False
# 366-1_3.jpg vs chung.png: False
# 366-1_3.jpg vs ng.png: False
# 368-12_0.jpg vs chang.png: False
# 368-12_0.jpg vs chung.png: False
# 368-12_0.jpg vs ng.png: False
# 368-12_1.jpg vs chang.png: False
# 368-12_1.jpg vs chung.png: False
# 368-12_1.jpg vs ng.png: False
# Error processing 368-12_10.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_10.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_10.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_11.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_11.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_11.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_3.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_5.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_6.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_7.jpg vs ng.png: Exception while processing img2_path
# Error processing 368-12_8.jpg vs chang.png: Exception while processing img2_path
# Error processing 368-12_8.jpg vs chung.png: Exception while processing img2_path
# Error processing 368-12_8.jpg vs ng.png: Exception while processing img2_path
# 368-12_9.jpg vs chang.png: False
# 368-12_9.jpg vs chung.png: False
# 368-12_9.jpg vs ng.png: False
# 369-15_0.jpg vs chang.png: False
# 369-15_0.jpg vs chung.png: False
# 369-15_0.jpg vs ng.png: False
# Error processing 369-15_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-15_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-15_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 369-16_0.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-16_0.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-16_0.jpg vs ng.png: Exception while processing img2_path
# 369-16_1.jpg vs chang.png: False
# 369-16_1.jpg vs chung.png: False
# 369-16_1.jpg vs ng.png: False
# Error processing 369-16_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-16_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-16_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 369-16_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-16_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-16_3.jpg vs ng.png: Exception while processing img2_path
# 369-16_4.jpg vs chang.png: False
# 369-16_4.jpg vs chung.png: False
# 369-16_4.jpg vs ng.png: False
# 369-16_5.jpg vs chang.png: False
# 369-16_5.jpg vs chung.png: False
# 369-16_5.jpg vs ng.png: False
# Error processing 369-16_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-16_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-16_6.jpg vs ng.png: Exception while processing img2_path
# 369-16_7.jpg vs chang.png: False
# 369-16_7.jpg vs chung.png: True
# 369-16_7.jpg vs ng.png: True
# 369-16_8.jpg vs chang.png: False
# 369-16_8.jpg vs chung.png: True
# 369-16_8.jpg vs ng.png: True
# Error processing 369-16_9.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-16_9.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-16_9.jpg vs ng.png: Exception while processing img2_path
# 369-17_0.jpg vs chang.png: True
# 369-17_0.jpg vs chung.png: False
# 369-17_0.jpg vs ng.png: False
# 369-17_1.jpg vs chang.png: False
# 369-17_1.jpg vs chung.png: False
# 369-17_1.jpg vs ng.png: False
# 369-17_2.jpg vs chang.png: False
# 369-17_2.jpg vs chung.png: True
# 369-17_2.jpg vs ng.png: True
# 369-17_3.jpg vs chang.png: False
# 369-17_3.jpg vs chung.png: False
# 369-17_3.jpg vs ng.png: False
# Error processing 369-17_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-17_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-17_4.jpg vs ng.png: Exception while processing img2_path
# 369-17_5.jpg vs chang.png: False
# 369-17_5.jpg vs chung.png: False
# 369-17_5.jpg vs ng.png: False
# Error processing 369-17_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-17_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-17_6.jpg vs ng.png: Exception while processing img2_path
# Error processing 369-17_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-17_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-17_7.jpg vs ng.png: Exception while processing img2_path
# Error processing 369-17_8.jpg vs chang.png: Exception while processing img2_path
# Error processing 369-17_8.jpg vs chung.png: Exception while processing img2_path
# Error processing 369-17_8.jpg vs ng.png: Exception while processing img2_path
# 372-1_0.jpg vs chang.png: False
# 372-1_0.jpg vs chung.png: True
# 372-1_0.jpg vs ng.png: True
# 372-1_1.jpg vs chang.png: False
# 372-1_1.jpg vs chung.png: False
# 372-1_1.jpg vs ng.png: False
# 372-1_2.jpg vs chang.png: False
# 372-1_2.jpg vs chung.png: False
# 372-1_2.jpg vs ng.png: False
# 372-1_3.jpg vs chang.png: False
# 372-1_3.jpg vs chung.png: False
# 372-1_3.jpg vs ng.png: False
# Error processing 372-1_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 372-1_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 372-1_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 372-1_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 372-1_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 372-1_5.jpg vs ng.png: Exception while processing img2_path
# 372-1_6.jpg vs chang.png: False
# 372-1_6.jpg vs chung.png: False
# 372-1_6.jpg vs ng.png: False
# Error processing 372-1_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 372-1_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 372-1_7.jpg vs ng.png: Exception while processing img2_path
# 374-11_0.jpg vs chang.png: False
# 374-11_0.jpg vs chung.png: False
# 374-11_0.jpg vs ng.png: False
# 374-11_1.jpg vs chang.png: False
# 374-11_1.jpg vs chung.png: False
# 374-11_1.jpg vs ng.png: False
# 374-11_10.jpg vs chang.png: False
# 374-11_10.jpg vs chung.png: False
# 374-11_10.jpg vs ng.png: False
# Error processing 374-11_11.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_11.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_11.jpg vs ng.png: Exception while processing img2_path
# Error processing 374-11_12.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_12.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_12.jpg vs ng.png: Exception while processing img2_path
# 374-11_13.jpg vs chang.png: False
# 374-11_13.jpg vs chung.png: False
# 374-11_13.jpg vs ng.png: False
# Error processing 374-11_14.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_14.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_14.jpg vs ng.png: Exception while processing img2_path
# 374-11_2.jpg vs chang.png: False
# 374-11_2.jpg vs chung.png: True
# 374-11_2.jpg vs ng.png: True
# 374-11_3.jpg vs chang.png: False
# 374-11_3.jpg vs chung.png: False
# 374-11_3.jpg vs ng.png: False
# 374-11_4.jpg vs chang.png: False
# 374-11_4.jpg vs chung.png: False
# 374-11_4.jpg vs ng.png: False
# Error processing 374-11_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_5.jpg vs ng.png: Exception while processing img2_path
# 374-11_6.jpg vs chang.png: False
# 374-11_6.jpg vs chung.png: False
# 374-11_6.jpg vs ng.png: False
# 374-11_7.jpg vs chang.png: False
# 374-11_7.jpg vs chung.png: False
# 374-11_7.jpg vs ng.png: False
# Error processing 374-11_8.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_8.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_8.jpg vs ng.png: Exception while processing img2_path
# Error processing 374-11_9.jpg vs chang.png: Exception while processing img2_path
# Error processing 374-11_9.jpg vs chung.png: Exception while processing img2_path
# Error processing 374-11_9.jpg vs ng.png: Exception while processing img2_path
# 388-13_0.jpg vs chang.png: False
# 388-13_0.jpg vs chung.png: False
# 388-13_0.jpg vs ng.png: True
# Error processing 388-13_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 388-13_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 388-13_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_3.jpg vs ng.png: Exception while processing img2_path
# Error processing 388-13_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 388-13_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_5.jpg vs ng.png: Exception while processing img2_path
# Error processing 388-13_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 388-13_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 388-13_6.jpg vs ng.png: Exception while processing img2_path
# 404-10_0.jpg vs chang.png: False
# 404-10_0.jpg vs chung.png: False
# 404-10_0.jpg vs ng.png: False
# Error processing 404-10_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 404-10_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 404-10_1.jpg vs ng.png: Exception while processing img2_path
# 404-10_2.jpg vs chang.png: False
# 404-10_2.jpg vs chung.png: False
# 404-10_2.jpg vs ng.png: False
# Error processing 404-10_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 404-10_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 404-10_3.jpg vs ng.png: Exception while processing img2_path
# Error processing 404-10_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 404-10_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 404-10_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 404-10_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 404-10_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 404-10_5.jpg vs ng.png: Exception while processing img2_path
# 416-4_0.jpg vs chang.png: False
# 416-4_0.jpg vs chung.png: False
# 416-4_0.jpg vs ng.png: False
# 416-4_1.jpg vs chang.png: False
# 416-4_1.jpg vs chung.png: False
# 416-4_1.jpg vs ng.png: True
# 416-4_2.jpg vs chang.png: False
# 416-4_2.jpg vs chung.png: False
# 416-4_2.jpg vs ng.png: False
# 416-4_3.jpg vs chang.png: False
# 416-4_3.jpg vs chung.png: False
# 416-4_3.jpg vs ng.png: False
# 416-4_4.jpg vs chang.png: False
# 416-4_4.jpg vs chung.png: False
# 416-4_4.jpg vs ng.png: False
# 416-4_5.jpg vs chang.png: False
# 416-4_5.jpg vs chung.png: False
# 416-4_5.jpg vs ng.png: True
# Error processing 416-4_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 416-4_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 416-4_6.jpg vs ng.png: Exception while processing img2_path
# Error processing 416-4_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 416-4_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 416-4_7.jpg vs ng.png: Exception while processing img2_path
# 419-15_0.jpg vs chang.png: False
# 419-15_0.jpg vs chung.png: False
# 419-15_0.jpg vs ng.png: True
# 419-15_1.jpg vs chang.png: False
# 419-15_1.jpg vs chung.png: True
# 419-15_1.jpg vs ng.png: True
# 419-15_2.jpg vs chang.png: False
# 419-15_2.jpg vs chung.png: True
# 419-15_2.jpg vs ng.png: True
# 419-15_3.jpg vs chang.png: False
# 419-15_3.jpg vs chung.png: False
# 419-15_3.jpg vs ng.png: True
# Error processing 419-15_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 419-15_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 419-15_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 419-15_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 419-15_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 419-15_5.jpg vs ng.png: Exception while processing img2_path
# Error processing 419-15_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 419-15_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 419-15_6.jpg vs ng.png: Exception while processing img2_path
# Error processing 419-15_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 419-15_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 419-15_7.jpg vs ng.png: Exception while processing img2_path
# 50-18_0.jpg vs chang.png: False
# 50-18_0.jpg vs chung.png: True
# 50-18_0.jpg vs ng.png: True
# 50-18_1.jpg vs chang.png: False
# 50-18_1.jpg vs chung.png: False
# 50-18_1.jpg vs ng.png: False
# 50-18_2.jpg vs chang.png: True
# 50-18_2.jpg vs chung.png: False
# 50-18_2.jpg vs ng.png: False
# Error processing 50-18_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-18_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-18_3.jpg vs ng.png: Exception while processing img2_path
# 50-20_0.jpg vs chang.png: True
# 50-20_0.jpg vs chung.png: False
# 50-20_0.jpg vs ng.png: False
# 50-20_1.jpg vs chang.png: False
# 50-20_1.jpg vs chung.png: False
# 50-20_1.jpg vs ng.png: False
# 50-20_2.jpg vs chang.png: False
# 50-20_2.jpg vs chung.png: True
# 50-20_2.jpg vs ng.png: False
# 50-20_3.jpg vs chang.png: False
# 50-20_3.jpg vs chung.png: False
# 50-20_3.jpg vs ng.png: False
# Error processing 50-20_4.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_4.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_4.jpg vs ng.png: Exception while processing img2_path
# Error processing 50-20_5.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_5.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_5.jpg vs ng.png: Exception while processing img2_path
# Error processing 50-20_6.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_6.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_6.jpg vs ng.png: Exception while processing img2_path
# Error processing 50-20_7.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_7.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_7.jpg vs ng.png: Exception while processing img2_path
# Error processing 50-20_8.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_8.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_8.jpg vs ng.png: Exception while processing img2_path
# Error processing 50-20_9.jpg vs chang.png: Exception while processing img2_path
# Error processing 50-20_9.jpg vs chung.png: Exception while processing img2_path
# Error processing 50-20_9.jpg vs ng.png: Exception while processing img2_path
# 627-19_0.jpg vs chang.png: False
# 627-19_0.jpg vs chung.png: False
# 627-19_0.jpg vs ng.png: False
# Error processing 627-19_1.jpg vs chang.png: Exception while processing img2_path
# Error processing 627-19_1.jpg vs chung.png: Exception while processing img2_path
# Error processing 627-19_1.jpg vs ng.png: Exception while processing img2_path
# Error processing 627-19_2.jpg vs chang.png: Exception while processing img2_path
# Error processing 627-19_2.jpg vs chung.png: Exception while processing img2_path
# Error processing 627-19_2.jpg vs ng.png: Exception while processing img2_path
# Error processing 627-19_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 627-19_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 627-19_3.jpg vs ng.png: Exception while processing img2_path
# 691-27_0.jpg vs chang.png: False
# 691-27_0.jpg vs chung.png: False
# 691-27_0.jpg vs ng.png: False
# 691-27_1.jpg vs chang.png: False
# 691-27_1.jpg vs chung.png: False
# 691-27_1.jpg vs ng.png: False
# 691-27_2.jpg vs chang.png: True
# 691-27_2.jpg vs chung.png: False
# 691-27_2.jpg vs ng.png: False
# 691-27_3.jpg vs chang.png: False
# 691-27_3.jpg vs chung.png: False
# 691-27_3.jpg vs ng.png: True
# 691-27_4.jpg vs chang.png: False
# 691-27_4.jpg vs chung.png: False
# 691-27_4.jpg vs ng.png: False
# 872-22_0.jpg vs chang.png: True
# 872-22_0.jpg vs chung.png: False
# 872-22_0.jpg vs ng.png: False
# 872-22_1.jpg vs chang.png: False
# 872-22_1.jpg vs chung.png: False
# 872-22_1.jpg vs ng.png: False
# 942_03_0.jpg vs chang.png: True
# 942_03_0.jpg vs chung.png: False
# 942_03_0.jpg vs ng.png: False
# 942_03_1.jpg vs chang.png: False
# 942_03_1.jpg vs chung.png: False
# 942_03_1.jpg vs ng.png: False
# 942_03_2.jpg vs chang.png: False
# 942_03_2.jpg vs chung.png: False
# 942_03_2.jpg vs ng.png: False
# Error processing 942_03_3.jpg vs chang.png: Exception while processing img2_path
# Error processing 942_03_3.jpg vs chung.png: Exception while processing img2_path
# Error processing 942_03_3.jpg vs ng.png: Exception while processing img2_path
# 942_04_0.jpg vs chang.png: False
# 942_04_0.jpg vs chung.png: True
# 942_04_0.jpg vs ng.png: True
# 942_04_1.jpg vs chang.png: True
# 942_04_1.jpg vs chung.png: False
# 942_04_1.jpg vs ng.png: False
# 942_04_2.jpg vs chang.png: True
# 942_04_2.jpg vs chung.png: False
# 942_04_2.jpg vs ng.png: False
# 942_04_3.jpg vs chang.png: True
# 942_04_3.jpg vs chung.png: False
# 942_04_3.jpg vs ng.png: False
# Error processing CER ANN_002_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_0.jpg vs ng.png: Exception while processing img2_path
# CER ANN_002_SM_1.jpg vs chang.png: False
# CER ANN_002_SM_1.jpg vs chung.png: False
# CER ANN_002_SM_1.jpg vs ng.png: False
# Error processing CER ANN_002_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing CER ANN_002_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing CER KEL_003_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing CER KEL_003_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing CER KEL_003_SM_0.jpg vs ng.png: Exception while processing img2_path
# CER KEL_003_SM_1.jpg vs chang.png: False
# CER KEL_003_SM_1.jpg vs chung.png: True
# CER KEL_003_SM_1.jpg vs ng.png: True
# CER KEL_003_SM_2.jpg vs chang.png: False
# CER KEL_003_SM_2.jpg vs chung.png: True
# CER KEL_003_SM_2.jpg vs ng.png: True
# CER W3C3_001_SM_0.jpg vs chang.png: False
# CER W3C3_001_SM_0.jpg vs chung.png: False
# CER W3C3_001_SM_0.jpg vs ng.png: False
# Error processing CER W3C3_001_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_10.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_10.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_10.jpg vs ng.png: Exception while processing img2_path
# CER W3C3_001_SM_2.jpg vs chang.png: False
# CER W3C3_001_SM_2.jpg vs chung.png: False
# CER W3C3_001_SM_2.jpg vs ng.png: False
# CER W3C3_001_SM_3.jpg vs chang.png: False
# CER W3C3_001_SM_3.jpg vs chung.png: False
# CER W3C3_001_SM_3.jpg vs ng.png: False
# CER W3C3_001_SM_4.jpg vs chang.png: False
# CER W3C3_001_SM_4.jpg vs chung.png: False
# CER W3C3_001_SM_4.jpg vs ng.png: True
# Error processing CER W3C3_001_SM_5.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_5.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_5.jpg vs ng.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_7.jpg vs ng.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_8.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_8.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_8.jpg vs ng.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_9.jpg vs chang.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_9.jpg vs chung.png: Exception while processing img2_path
# Error processing CER W3C3_001_SM_9.jpg vs ng.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_1.jpg vs ng.png: Exception while processing img2_path
# CMT UCL_009_SM_2.jpg vs chang.png: False
# CMT UCL_009_SM_2.jpg vs chung.png: False
# CMT UCL_009_SM_2.jpg vs ng.png: False
# Error processing CMT UCL_009_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing CMT UCL_009_SM_3.jpg vs ng.png: Exception while processing img2_path
# CMT UCL_009_SM_4.jpg vs chang.png: False
# CMT UCL_009_SM_4.jpg vs chung.png: False
# CMT UCL_009_SM_4.jpg vs ng.png: False
# Error processing Cnews SP 99_P8-3_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing Cnews SP 99_P8-3_SM_3.jpg vs ng.png: Exception while processing img2_path
# CONF HERA_004_SM_0.jpg vs chang.png: False
# CONF HERA_004_SM_0.jpg vs chung.png: True
# CONF HERA_004_SM_0.jpg vs ng.png: False
# CONF HERA_004_SM_1.jpg vs chang.png: False
# CONF HERA_004_SM_1.jpg vs chung.png: True
# CONF HERA_004_SM_1.jpg vs ng.png: False
# CONF HERA_004_SM_2.jpg vs chang.png: False
# CONF HERA_004_SM_2.jpg vs chung.png: False
# CONF HERA_004_SM_2.jpg vs ng.png: False
# CONF HERA_004_SM_3.jpg vs chang.png: False
# CONF HERA_004_SM_3.jpg vs chung.png: False
# CONF HERA_004_SM_3.jpg vs ng.png: False
# CONF HERA_004_SM_4.jpg vs chang.png: False
# CONF HERA_004_SM_4.jpg vs chung.png: False
# CONF HERA_004_SM_4.jpg vs ng.png: False
# CONF HERA_004_SM_5.jpg vs chang.png: False
# CONF HERA_004_SM_5.jpg vs chung.png: False
# CONF HERA_004_SM_5.jpg vs ng.png: False
# Error processing CONF HERA_004_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing CONF HERA_004_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing CONF HERA_004_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing CONF HERA_004_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing CONF HERA_004_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing CONF HERA_004_SM_7.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_0.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_0.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_0.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_1.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_1.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_1.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_10.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_10.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_10.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_11.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_11.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_11.jpg vs ng.png: Exception while processing img2_path
# CONG 1_013_SM8_12.jpg vs chang.png: False
# CONG 1_013_SM8_12.jpg vs chung.png: False
# CONG 1_013_SM8_12.jpg vs ng.png: False
# Error processing CONG 1_013_SM8_13.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_13.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_13.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_14.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_14.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_14.jpg vs ng.png: Exception while processing img2_path
# CONG 1_013_SM8_2.jpg vs chang.png: False
# CONG 1_013_SM8_2.jpg vs chung.png: False
# CONG 1_013_SM8_2.jpg vs ng.png: False
# Error processing CONG 1_013_SM8_3.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_3.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_3.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_4.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_4.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_4.jpg vs ng.png: Exception while processing img2_path
# CONG 1_013_SM8_5.jpg vs chang.png: False
# CONG 1_013_SM8_5.jpg vs chung.png: False
# CONG 1_013_SM8_5.jpg vs ng.png: False
# CONG 1_013_SM8_6.jpg vs chang.png: False
# CONG 1_013_SM8_6.jpg vs chung.png: False
# CONG 1_013_SM8_6.jpg vs ng.png: False
# Error processing CONG 1_013_SM8_7.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_7.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_7.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_8.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_8.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_8.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_9.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_9.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 1_013_SM8_9.jpg vs ng.png: Exception while processing img2_path
# CONG 7_011_0.jpg vs chang.png: False
# CONG 7_011_0.jpg vs chung.png: False
# CONG 7_011_0.jpg vs ng.png: False
# Error processing CONG 7_011_1.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_1.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_1.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 7_011_2.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_2.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_2.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 7_011_3.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_3.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_3.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 7_011_4.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_4.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_4.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 7_011_5.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_5.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_5.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG 7_011_6.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG 7_011_6.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG 7_011_6.jpg vs ng.png: Exception while processing img2_path
# CONG 7_044_0.jpg vs chang.png: False
# CONG 7_044_0.jpg vs chung.png: False
# CONG 7_044_0.jpg vs ng.png: False
# CONG 7_044_1.jpg vs chang.png: False
# CONG 7_044_1.jpg vs chung.png: True
# CONG 7_044_1.jpg vs ng.png: True
# CONG5_055_SM_0.jpg vs chang.png: True
# CONG5_055_SM_0.jpg vs chung.png: False
# CONG5_055_SM_0.jpg vs ng.png: False
# Error processing CONG5_055_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_10.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_10.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_10.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_11.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_11.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_11.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_12.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_12.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_12.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_4.jpg vs ng.png: Exception while processing img2_path
# CONG5_055_SM_5.jpg vs chang.png: False
# CONG5_055_SM_5.jpg vs chung.png: False
# CONG5_055_SM_5.jpg vs ng.png: False
# Error processing CONG5_055_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing CONG5_055_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_7.jpg vs ng.png: Exception while processing img2_path
# CONG5_055_SM_8.jpg vs chang.png: False
# CONG5_055_SM_8.jpg vs chung.png: False
# CONG5_055_SM_8.jpg vs ng.png: True
# Error processing CONG5_055_SM_9.jpg vs chang.png: Exception while processing img2_path
# Error processing CONG5_055_SM_9.jpg vs chung.png: Exception while processing img2_path
# Error processing CONG5_055_SM_9.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_002_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_005_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_006_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_006_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_006_SM_0.jpg vs ng.png: Exception while processing img2_path
# COU ACI_006_SM_1.jpg vs chang.png: False
# COU ACI_006_SM_1.jpg vs chung.png: False
# COU ACI_006_SM_1.jpg vs ng.png: False
# Error processing COU ACI_007_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_007_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_007_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_007_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_007_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_007_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_1.jpg vs ng.png: Exception while processing img2_path
# COU ACI_013_SM_2.jpg vs chang.png: False
# COU ACI_013_SM_2.jpg vs chung.png: False
# COU ACI_013_SM_2.jpg vs ng.png: False
# Error processing COU ACI_013_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_013_SM_3.jpg vs ng.png: Exception while processing img2_path
# COU ACI_105_SM_0.jpg vs chang.png: False
# COU ACI_105_SM_0.jpg vs chung.png: False
# COU ACI_105_SM_0.jpg vs ng.png: False
# Error processing COU ACI_105_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing COU ACI_105_SM_4.jpg vs ng.png: Exception while processing img2_path
# COU INA_001_SM_0.jpg vs chang.png: False
# COU INA_001_SM_0.jpg vs chung.png: False
# COU INA_001_SM_0.jpg vs ng.png: False
# Error processing COU INA_001_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing COU INA_001_SM_1.jpg vs chung.png: Exception while processing img2_path
# ...
# Error processing Patten Visit_1-10_23.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_24.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_24.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_24.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_25.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_25.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_25.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_26.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_26.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_26.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_27.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_27.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_27.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_28.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_28.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_28.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_3.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_3.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_3.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_4.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_4.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_4.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_5.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_5.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_5.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_6.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_6.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_6.jpg vs ng.png: Exception while processing img2_path
# Patten Visit_1-10_7.jpg vs chang.png: False
# Patten Visit_1-10_7.jpg vs chung.png: False
# Patten Visit_1-10_7.jpg vs ng.png: False
# Error processing Patten Visit_1-10_8.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_8.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_8.jpg vs ng.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_9.jpg vs chang.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_9.jpg vs chung.png: Exception while processing img2_path
# Error processing Patten Visit_1-10_9.jpg vs ng.png: Exception while processing img2_path
# TOP STU_008_SM_0.jpg vs chang.png: False
# TOP STU_008_SM_0.jpg vs chung.png: False
# TOP STU_008_SM_0.jpg vs ng.png: False
# TOP STU_008_SM_1.jpg vs chang.png: False
# TOP STU_008_SM_1.jpg vs chung.png: False
# TOP STU_008_SM_1.jpg vs ng.png: False
# TOP STU_008_SM_2.jpg vs chang.png: False
# TOP STU_008_SM_2.jpg vs chung.png: True
# TOP STU_008_SM_2.jpg vs ng.png: True
# Error processing TOP STU_008_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing TOP STU_008_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing TOP STU_008_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing TOP STU_008_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing TOP STU_008_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing TOP STU_008_SM_4.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_0.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_0.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_0.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_1.jpg vs ng.png: Exception while processing img2_path
# VIS A_LAM_015_SM_2.jpg vs chang.png: False
# VIS A_LAM_015_SM_2.jpg vs chung.png: False
# VIS A_LAM_015_SM_2.jpg vs ng.png: False
# Error processing VIS A_LAM_015_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_3.jpg vs ng.png: Exception while processing img2_path
# VIS A_LAM_015_SM_4.jpg vs chang.png: False
# VIS A_LAM_015_SM_4.jpg vs chung.png: False
# VIS A_LAM_015_SM_4.jpg vs ng.png: False
# Error processing VIS A_LAM_015_SM_5.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_5.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_5.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS A_LAM_015_SM_6.jpg vs ng.png: Exception while processing img2_path
# VIS DBC_015_SM_0.jpg vs chang.png: False
# VIS DBC_015_SM_0.jpg vs chung.png: True
# VIS DBC_015_SM_0.jpg vs ng.png: True
# Error processing VIS DBC_015_SM_1.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_1.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_1.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_2.jpg vs ng.png: Exception while processing img2_path
# VIS DBC_015_SM_3.jpg vs chang.png: False
# VIS DBC_015_SM_3.jpg vs chung.png: False
# VIS DBC_015_SM_3.jpg vs ng.png: False
# Error processing VIS DBC_015_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_4.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_5.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_5.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_5.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS DBC_015_SM_7.jpg vs ng.png: Exception while processing img2_path
# VIS M THATCHER_X4_SM_0.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_0.jpg vs chung.png: False
# VIS M THATCHER_X4_SM_0.jpg vs ng.png: False
# VIS M THATCHER_X4_SM_1.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_1.jpg vs chung.png: False
# VIS M THATCHER_X4_SM_1.jpg vs ng.png: False
# Error processing VIS M THATCHER_X4_SM_10.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_10.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_10.jpg vs ng.png: Exception while processing img2_path
# VIS M THATCHER_X4_SM_2.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_2.jpg vs chung.png: False
# VIS M THATCHER_X4_SM_2.jpg vs ng.png: False
# VIS M THATCHER_X4_SM_3.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_3.jpg vs chung.png: True
# VIS M THATCHER_X4_SM_3.jpg vs ng.png: True
# Error processing VIS M THATCHER_X4_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_4.jpg vs ng.png: Exception while processing img2_path
# VIS M THATCHER_X4_SM_5.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_5.jpg vs chung.png: False
# VIS M THATCHER_X4_SM_5.jpg vs ng.png: False
# Error processing VIS M THATCHER_X4_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_7.jpg vs ng.png: Exception while processing img2_path
# VIS M THATCHER_X4_SM_8.jpg vs chang.png: False
# VIS M THATCHER_X4_SM_8.jpg vs chung.png: False
# VIS M THATCHER_X4_SM_8.jpg vs ng.png: False
# Error processing VIS M THATCHER_X4_SM_9.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_9.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS M THATCHER_X4_SM_9.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_002_SM_0.jpg vs chang.png: False
# VIS PAT_002_SM_0.jpg vs chung.png: False
# VIS PAT_002_SM_0.jpg vs ng.png: False
# VIS PAT_002_SM_1.jpg vs chang.png: False
# VIS PAT_002_SM_1.jpg vs chung.png: True
# VIS PAT_002_SM_1.jpg vs ng.png: True
# Error processing VIS PAT_002_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_002_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_002_SM_2.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_002_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_002_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_002_SM_3.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_018_SM_0.jpg vs chang.png: False
# VIS PAT_018_SM_0.jpg vs chung.png: False
# VIS PAT_018_SM_0.jpg vs ng.png: False
# VIS PAT_018_SM_1.jpg vs chang.png: False
# VIS PAT_018_SM_1.jpg vs chung.png: False
# VIS PAT_018_SM_1.jpg vs ng.png: False
# Error processing VIS PAT_018_SM_10.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_10.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_10.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_018_SM_11.jpg vs chang.png: False
# VIS PAT_018_SM_11.jpg vs chung.png: False
# VIS PAT_018_SM_11.jpg vs ng.png: False
# Error processing VIS PAT_018_SM_12.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_12.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_12.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_018_SM_2.jpg vs chang.png: False
# VIS PAT_018_SM_2.jpg vs chung.png: False
# VIS PAT_018_SM_2.jpg vs ng.png: False
# Error processing VIS PAT_018_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_3.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_018_SM_4.jpg vs chang.png: False
# VIS PAT_018_SM_4.jpg vs chung.png: False
# VIS PAT_018_SM_4.jpg vs ng.png: False
# Error processing VIS PAT_018_SM_5.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_5.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_5.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_6.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_018_SM_7.jpg vs chang.png: False
# VIS PAT_018_SM_7.jpg vs chung.png: False
# VIS PAT_018_SM_7.jpg vs ng.png: False
# Error processing VIS PAT_018_SM_8.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_8.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_8.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_9.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_9.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_018_SM_9.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_021_SM_0.jpg vs chang.png: False
# VIS PAT_021_SM_0.jpg vs chung.png: False
# VIS PAT_021_SM_0.jpg vs ng.png: False
# VIS PAT_021_SM_1.jpg vs chang.png: False
# VIS PAT_021_SM_1.jpg vs chung.png: False
# VIS PAT_021_SM_1.jpg vs ng.png: True
# Error processing VIS PAT_021_SM_2.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_2.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_2.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_021_SM_3.jpg vs chang.png: False
# VIS PAT_021_SM_3.jpg vs chung.png: False
# VIS PAT_021_SM_3.jpg vs ng.png: False
# VIS PAT_021_SM_4.jpg vs chang.png: False
# VIS PAT_021_SM_4.jpg vs chung.png: True
# VIS PAT_021_SM_4.jpg vs ng.png: False
# VIS PAT_021_SM_5.jpg vs chang.png: False
# VIS PAT_021_SM_5.jpg vs chung.png: False
# VIS PAT_021_SM_5.jpg vs ng.png: False
# Error processing VIS PAT_021_SM_6.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_6.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_6.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_7.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_7.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_7.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_8.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_8.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_8.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_9.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_9.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_021_SM_9.jpg vs ng.png: Exception while processing img2_path
# VIS PAT_042_SM_0.jpg vs chang.png: False
# VIS PAT_042_SM_0.jpg vs chung.png: False
# VIS PAT_042_SM_0.jpg vs ng.png: False
# VIS PAT_042_SM_1.jpg vs chang.png: False
# VIS PAT_042_SM_1.jpg vs chung.png: False
# VIS PAT_042_SM_1.jpg vs ng.png: True
# VIS PAT_042_SM_2.jpg vs chang.png: False
# VIS PAT_042_SM_2.jpg vs chung.png: False
# VIS PAT_042_SM_2.jpg vs ng.png: False
# Error processing VIS PAT_042_SM_3.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_042_SM_3.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_042_SM_3.jpg vs ng.png: Exception while processing img2_path
# Error processing VIS PAT_042_SM_4.jpg vs chang.png: Exception while processing img2_path
# Error processing VIS PAT_042_SM_4.jpg vs chung.png: Exception while processing img2_path
# Error processing VIS PAT_042_SM_4.jpg vs ng.png: Exception while processing img2_path

# %% [markdown]
# ---
# # Example of the parameter in the output of deepface
# https://github.com/serengil/deepface
#
# Parameter
# - `verified`: True or False
# - `distance`: the lower the value, the more similar
# - `threshold`: compare with `distance`, e.g.
#     - 'distance': 0.23513354415109855 < 'threshold': 0.4 = 'verified': True (similar)
#     - 'distance': 0.48615039519636505 > 'threshold': 0.4 = 'verified': False (not similar)

# %%
# face matching - test if the same person
img1_path = "ng1.jpg"
img2_path = "ng5.jpg"
model_name = 'Facenet'
result = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name)
print(result)
# Out:
# {'verified': True, 'distance': 0.23513359003463996, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 405, 'y': 154, 'w': 308, 'h': 308, 'left_eye': None, 'right_eye': None}, 'img2': {'x': 66, 'y': 45, 'w': 125, 'h': 125, 'left_eye': None, 'right_eye': None}}, 'time': 3.83}

# %%
# face matching - test if different person
img1_path = "ng1.jpg"
img2_path = "ngX.jpg" 
model_name = 'Facenet'
result = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = model_name)
print(result)
# Out:
# {'verified': False, 'distance': 0.48615030675596227, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 405, 'y': 154, 'w': 308, 'h': 308, 'left_eye': None, 'right_eye': None}, 'img2': {'x': 83, 'y': 78, 'w': 142, 'h': 142, 'left_eye': (176, 135), 'right_eye': (130, 133)}}, 'time': 0.56}
